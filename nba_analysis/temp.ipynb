# %%
import pandas as pd
import numpy as np

# %%
data = {
  "x1":[1,2,3,4,np.nan,np.nan,np.nan,8,9],
  "y1":[1,2,3,4,np.nan,np.nan,np.nan,8,9],
  "x2":[1,2,3,4,np.nan,np.nan,np.nan,8,9],
  "y2":[1,2,3,4,np.nan,np.nan,np.nan,8,9]
}

# %%
df = pd.DataFrame(data)
df

# %%
df.interpolate()
