# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\group\appdata\roaming\python\python312\site-packages (8.3.162)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (3.9.3)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (6.1.1)
# Requirement already satisfied: py-cpuinfo in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\group\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\group\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\group\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\group\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\group\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\group\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in c:\users\group\appdata\roaming\python\python312\site-packages (1.2.0)
# Requirement already satisfied: certifi in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (2024.8.30)
# Requirement already satisfied: idna==3.7 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (3.9.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (2.3.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pillow-heif<2 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\group\appdata\roaming\python\python312\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\group\appdata\roaming\python\python312\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (4.55.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\group\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\group\appdata\roaming\python\python312\site-packages (from requests->roboflow) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import os
import random
import shutil
import matplotlib.pyplot as plt
from roboflow import Roboflow

# %%
roboflow_api_key = "Wc0gPTScXi1S4o4HJPVF"

# from roboflow import Roboflow
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("easyaiedu").project("nba-court-keypoint-detection-u9n5v")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in NBA-court-keypoint-detection-1 to yolov8:: 100%|██████████| 13183/13183 [00:02<00:00, 4599.22it/s]
# Extracting Dataset Version Zip to NBA-court-keypoint-detection-1 in yolov8:: 100%|██████████| 172/172 [00:00<00:00, 843.13it/s]

# %%
# %yolo task=pose mode=train model=yolov8x-pose.pt data={dataset.location}/data.yaml batch=4 epochs=10 imgsz=640
# Out:
# UsageError: Line magic function `%yolo` not found.

# %%
dataset.location
# Out:
# 'd:\\charlesDevelopment\\Machine-Learning-Web\\nba_analysis\\training\\NBA-court-keypoint-detection-1'

# %%
# shutil.move("reloc2-1/train",
# "reloc2-1/reloc2-1/train",
# )
# shutil.move("reloc2-1/valid",
# "reloc2-1/reloc2-1/valid",
# )
# shutil.move("reloc2-1/test",
# "reloc2-1/reloc2-1/test",
# )
# Out:
# 'reloc2-1/reloc2-1/test'

# %%
# dataset.location
# Out:
# 'd:\\charlesDevelopment\\Machine-Learning-Web\\nba_analysis\\training\\reloc2-1'

# %%
# from ultralytics import YOLO

# model = YOLO('yolov8x.pt')

# result = model.train(
#   data=f'{dataset.location}/data.yaml',
#   epochs=10,
#   imgsz=640,
#   task='detect'
# )

# %%
from ultralytics import YOLO

model = YOLO('yolov8x-pose.pt')

result = model.train(
  data=f'{dataset.location}/data.yaml',
  epochs=50,
  imgsz=640,
  task='pose',
  plots=True,
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x-pose.pt to 'yolov8x-pose.pt'...
# 100%|██████████| 133M/133M [01:46<00:00, 1.31MB/s]
# New https://pypi.org/project/ultralytics/8.3.169 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.162  Python-3.12.7 torch-2.6.0+cpu CPU (Intel Xeon E3-1535M v5 2.90GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=d:\charlesDevelopment\Machine-Learning-Web\nba_analysis\training\NBA-court-keypoint-detection-1/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\pose\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[22, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1  10060729  ultralytics.nn.modules.head.Pose             [1, [22, 3], [320, 640, 640]]
# YOLOv8x-pose summary: 224 layers, 69,495,369 parameters, 69,495,353 gradients, 264.0 GFLOPs
#
# Transferred 631/637 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.30.0 ms, read: 12.22.0 MB/s, size: 169.2 KB)
# train: Scanning D:\charlesDevelopment\Machine-Learning-Web\nba_analysis\training\NBA-court-keypoint-detection-1\train\labels... 56 images, 0 backgrounds, 0 corrupt: 100%|██████████| 56/56 [00:00<00:00, 150.13it/s]
# train: New cache created: D:\charlesDevelopment\Machine-Learning-Web\nba_analysis\training\NBA-court-keypoint-detection-1\train\labels.cache
# val: Fast image access  (ping: 0.30.2 ms, read: 6.53.3 MB/s, size: 146.4 KB)
# val: Scanning D:\charlesDevelopment\Machine-Learning-Web\nba_analysis\training\NBA-court-keypoint-detection-1\valid\labels... 16 images, 0 backgrounds, 1 corrupt: 100%|██████████| 16/16 [00:00<00:00, 125.98it/s]
# val: D:\charlesDevelopment\Machine-Learning-Web\nba_analysis\training\NBA-court-keypoint-detection-1\valid\images\0022300589-65_08_jpg.rf.4bbef986b47a92f661dcc39066e09b44.jpg: ignoring corrupt image/label: negative label values [-0.00173944 -0.00158875 -0.00145653 -0.00145653 -0.00124347 -0.00123611
#  -0.00108181 -0.00098986 -0.00174681 -0.00160347 -0.00145653 -0.00123972
#  -0.00107444]
# val: New cache created: D:\charlesDevelopment\Machine-Learning-Web\nba_analysis\training\NBA-court-keypoint-detection-1\valid\labels.cache
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\GROUP\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\GROUP\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\GROUP\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\GROUP\AppData\Local\Temp\ipykernel_14596\1894947783.py", line 5, in <module>
#     result = model.train(
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py", line 799, in train
#     self.trainer.train()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 227, in train
#     self._do_train(world_size)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 348, in _do_train
#     self._setup_train(world_size)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 323, in _setup_train
#     self.plot_training_labels()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\models\yolo\detect\train.py", line 205, in plot_training_labels
#     plot_labels(boxes, cls.squeeze(), names=self.data["names"], save_dir=self.save_dir, on_plot=self.on_plot)
#   File "c:\Users\GROUP\anaconda3\Lib\contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\__init__.py", line 496, in wrapper
#     result = func(*args, **kwargs)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\plotting.py", line 566, in plot_labels
#     import pandas
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "c:\Users\GROUP\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "c:\Users\GROUP\anaconda3\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\GROUP\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\GROUP\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\GROUP\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\GROUP\AppData\Local\Temp\ipykernel_14596\1894947783.py", line 5, in <module>
#     result = model.train(
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py", line 799, in train
#     self.trainer.train()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 227, in train
#     self._do_train(world_size)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 348, in _do_train
#     self._setup_train(world_size)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 323, in _setup_train
#     self.plot_training_labels()
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\models\yolo\detect\train.py", line 205, in plot_training_labels
#     plot_labels(boxes, cls.squeeze(), names=self.data["names"], save_dir=self.save_dir, on_plot=self.on_plot)
#   File "c:\Users\GROUP\anaconda3\Lib\contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\__init__.py", line 496, in wrapper
#     result = func(*args, **kwargs)
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\plotting.py", line 566, in plot_labels
#     import pandas
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\GROUP\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "c:\Users\GROUP\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "c:\Users\GROUP\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# Plotting labels to runs\pose\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 103 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\pose\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      2.043       10.7     0.8425       5.22      2.211         25        640: 100%|██████████| 4/4 [10:07<00:00, 151.90s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:34<00:00, 34.14s/it]
#                    all         15         15      0.867      0.933      0.972      0.476          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G     0.7383      10.21     0.8525     0.7895      1.263         23        640: 100%|██████████| 4/4 [12:53<00:00, 193.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:31<00:00, 31.99s/it]
#                    all         15         15      0.994          1      0.995      0.974          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G     0.7156      10.31     0.7652     0.7199      1.252         21        640: 100%|██████████| 4/4 [11:44<00:00, 176.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:27<00:00, 27.86s/it]
#                    all         15         15      0.778      0.933      0.929      0.896          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G     0.6944      9.899     0.7332     0.7995      1.234         24        640: 100%|██████████| 4/4 [12:24<00:00, 186.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:24<00:00, 24.41s/it]
#                    all         15         15        0.5      0.333      0.463      0.191          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G     0.7176      10.21     0.6986     0.8028      1.233         23        640: 100%|██████████| 4/4 [09:37<00:00, 144.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:20<00:00, 20.66s/it]
#                    all         15         15   0.000921     0.0667     0.0014    0.00028          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G     0.6408      10.48     0.6467     0.5875       1.17         26        640: 100%|██████████| 4/4 [09:25<00:00, 141.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:27<00:00, 27.26s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G     0.6962      9.813     0.6485     0.6424      1.182         23        640: 100%|██████████| 4/4 [11:58<00:00, 179.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:20<00:00, 20.17s/it]
#                    all         15         15      0.143        0.4     0.0963     0.0255          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G     0.8571      10.01     0.6357     0.7362      1.294         27        640: 100%|██████████| 4/4 [10:04<00:00, 151.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:17<00:00, 17.07s/it]
#                    all         15         15     0.0144        0.2    0.00466    0.00174          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G     0.8255      10.11     0.6108     0.7389      1.269         29        640: 100%|██████████| 4/4 [10:36<00:00, 159.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:19<00:00, 19.88s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G     0.7656      9.861     0.5924     0.7747      1.212         22        640: 100%|██████████| 4/4 [07:15<00:00, 108.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:22<00:00, 22.86s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G     0.6391      9.962     0.5562     0.6418        1.2         24        640: 100%|██████████| 4/4 [08:54<00:00, 133.69s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:35<00:00, 35.15s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G     0.6875      10.13     0.5487     0.6614      1.195         23        640: 100%|██████████| 4/4 [10:38<00:00, 159.55s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:25<00:00, 25.60s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      0.801      9.929     0.5092     0.7392      1.294         20        640: 100%|██████████| 4/4 [08:52<00:00, 133.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:22<00:00, 22.01s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G     0.6909      10.04     0.5249     0.7127      1.203         24        640: 100%|██████████| 4/4 [06:44<00:00, 101.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:19<00:00, 19.36s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G     0.6018      9.913     0.5021     0.6084      1.164         24        640: 100%|██████████| 4/4 [07:59<00:00, 119.83s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:32<00:00, 32.39s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G     0.6683      9.991     0.4847     0.6389      1.194         18        640: 100%|██████████| 4/4 [13:48<00:00, 207.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:30<00:00, 30.26s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G      0.676      10.19     0.5035     0.6125      1.139         25        640: 100%|██████████| 4/4 [10:28<00:00, 157.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:23<00:00, 23.14s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G     0.6811      9.898     0.4809     0.6752      1.205         28        640: 100%|██████████| 4/4 [08:31<00:00, 127.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:21<00:00, 21.46s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G     0.7435      9.963     0.4807      0.696      1.234         22        640: 100%|██████████| 4/4 [10:39<00:00, 159.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:18<00:00, 18.40s/it]
#                    all         15         15        0.4      0.133     0.0644     0.0347          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G     0.7537      10.07     0.4937     0.6864      1.201         30        640: 100%|██████████| 4/4 [07:39<00:00, 114.82s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:21<00:00, 21.73s/it]
#                    all         15         15          0          0          0          0          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G     0.6766      9.889     0.4715     0.6207      1.188         29        640: 100%|██████████| 4/4 [07:46<00:00, 116.63s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:19<00:00, 19.90s/it]
#                    all         15         15       0.17      0.133     0.0711     0.0301          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G     0.6076      9.731     0.4452       0.55      1.157         28        640: 100%|██████████| 4/4 [08:12<00:00, 123.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:16<00:00, 16.37s/it]
#                    all         15         15      0.168       0.23      0.181     0.0289          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.6845      10.52     0.4855     0.6241       1.19         50        640:  25%|██▌       | 1/4 [01:46<05:18, 106.15s/it]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# %yolo task=pose mode=train model=yolov8x-pose.pt data={dataset.location}/data.yaml batch=4 epochs=10 imgsz=640
