# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import cv2
import numpy as np
import os
import random
import shutil
import matplotlib.pyplot as plt
from roboflow import Roboflow

# %%
# !pip install roboflow

roboflow_api_key = "Wc0gPTScXi1S4o4HJPVF"

# from roboflow import Roboflow
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("easyaiedu").project("nba-court-keypoint-detection-u9n5v")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to NBA-court-keypoint-detection-1 in yolov8:: 100%|██████████| 172/172 [00:00<00:00, 1154.07it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# roboflow_api_key = ""
# rf = Roboflow(api_key=roboflow_api_key )
# project = rf.workspace("fyp-3bwmg").project("reloc2-den7l")
# version = project.version(1)
# dataset = version.download("yolov8")

# %%
# %yolo task=pose mode=train model=yolov8x-pose.pt data={dataset.location}/data.yaml batch=4 epochs=10 imgsz=640

# %%
dataset.location
# Out:
# '/content/NBA-court-keypoint-detection-1'

# %%
# shutil.move("reloc2-1/train",
# "reloc2-1/reloc2-1/train",
# )
# shutil.move("reloc2-1/valid",
# "reloc2-1/reloc2-1/valid",
# )
# shutil.move("reloc2-1/test",
# "reloc2-1/reloc2-1/test",
# )

# %%
dataset.location
# Out:
# '/content/NBA-court-keypoint-detection-1'

# %%
# from ultralytics import YOLO

# model = YOLO('yolov8x.pt')

# result = model.train(
#   data=f'{dataset.location}/data.yaml',
#   epochs=10,
#   imgsz=640,
#   task='detect'
# )

# %%
# # Load a model
# from ultralytics import YOLO
# model = YOLO('yolov8x-pose.pt')  # load a pretrained model

# # Train the model
# results = model.train(
#     data=f'{dataset.location}/data.yaml',
#     epochs=100,
#     imgsz=640,
#     plots=True
# )

# %%
# !yolo task=pose mode=train model=yolov8x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=100 imgsz=640
# Out:
# ...
# 100% 133M/133M [00:04<00:00, 34.2MB/s]
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
